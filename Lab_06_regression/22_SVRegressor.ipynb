# %% [markdown]
# # Support Vector Regression
#
# There are three different implementations of Support Vector Regression:
# SVR, NuSVR and LinearSVR.
#
# LinearSVR provides a faster implementation than SVR but only considers linear kernels,
# while NuSVR implements a slightly different formulation than SVR and LinearSVR.
#
# See Implementation details for further details.

# %%
#Boston Housing Dataset: Load the boston dataset.
from sklearn.datasets import load_boston
boston = load_boston()

#Creating feature and target arrays
X, y = boston.data, boston.target
columns = boston.feature_names

X=X[y<50]
y=y[y<50]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler(copy=False).fit(X)
scaler.transform(X)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size=0.3,
                                                    random_state=42)
# Out:
# /home/mausoto/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %% [markdown]
# ## The Optimization Problem
#
# $$
# \begin{align}\begin{aligned}\min_ {w, b, \zeta, \zeta^*} \frac{1}{2} ||w||^2 + C \sum_{i=1}^{n} (\zeta_i + \zeta_i^*)\\\begin{split}\textrm {subject to } & y_i - (w^T \phi (x_i) + b) \leq \varepsilon + \zeta_i,\\
#                       & (w^T \phi (x_i) + b) - y_i \leq \varepsilon + \zeta_i^*,\\
#                       & \zeta_i, \zeta_i^* \geq 0, i=1, ..., n\end{split}\end{aligned}\end{align}
# $$
#
# where $\phi$ is the kernel map that can be chosen as
#  - linear: $\langle x, x'\rangle$
#  - poly: $(\gamma \langle x, x'\rangle + r)^d$ where $\gamma,\, d ,\, r$ are specified by keyword gamma, degree and coef0 respectively.
#  - rbf - radial basis function: $\exp(-\gamma \|x-x'\|^2)$
#  - neural networks (sigmoid): $\tanh(\gamma \langle x,x'\rangle + r)$

# %%
#DEFINE YOUR REGRESSOR and THE PARAMETERS GRID
from sklearn.svm import SVR
import numpy as np

regressor = SVR()
parameters = {'C': [0.1, 1, 10],
             'epsilon': [0.001, 0.01, 1],
             'gamma':['auto'],
             'kernel': ['linear', 'poly','rbf'],
             'degree': [2,3,5]
             }

#DEFINE YOUR GRIDSEARCH 
from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(regressor, parameters, cv=3, verbose = 10,scoring ='neg_mean_absolute_error') #with no params it reduces to a CV

gs = gs.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [CV 1/3; 1/81] START C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=linear..
# [CV 1/3; 1/81] END C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 1/81] START C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=linear..
# [CV 2/3; 1/81] END C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 1/81] START C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=linear..
# [CV 3/3; 1/81] END C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 2/81] START C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=poly....
# [CV 1/3; 2/81] END C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 2/81] START C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=poly....
# [CV 2/3; 2/81] END C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 2/81] START C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=poly....
# [CV 3/3; 2/81] END C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 3/81] START C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=rbf.....
# [CV 1/3; 3/81] END C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 3/81] START C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=rbf.....
# [CV 2/3; 3/81] END C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 3/81] START C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=rbf.....
# [CV 3/3; 3/81] END C=0.1, degree=2, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 4/81] START C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=linear...
# [CV 1/3; 4/81] END C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 4/81] START C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=linear...
# [CV 2/3; 4/81] END C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 4/81] START C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=linear...
# [CV 3/3; 4/81] END C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 5/81] START C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=poly.....
# [CV 1/3; 5/81] END C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 5/81] START C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=poly.....
# [CV 2/3; 5/81] END C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 5/81] START C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=poly.....
# [CV 3/3; 5/81] END C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 6/81] START C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=rbf......
# [CV 1/3; 6/81] END C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 6/81] START C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=rbf......
# [CV 2/3; 6/81] END C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 6/81] START C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=rbf......
# [CV 3/3; 6/81] END C=0.1, degree=2, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 7/81] START C=0.1, degree=2, epsilon=1, gamma=auto, kernel=linear......
# [CV 1/3; 7/81] END C=0.1, degree=2, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 7/81] START C=0.1, degree=2, epsilon=1, gamma=auto, kernel=linear......
# [CV 2/3; 7/81] END C=0.1, degree=2, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 7/81] START C=0.1, degree=2, epsilon=1, gamma=auto, kernel=linear......
# [CV 3/3; 7/81] END C=0.1, degree=2, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 8/81] START C=0.1, degree=2, epsilon=1, gamma=auto, kernel=poly........
# [CV 1/3; 8/81] END C=0.1, degree=2, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 8/81] START C=0.1, degree=2, epsilon=1, gamma=auto, kernel=poly........
# [CV 2/3; 8/81] END C=0.1, degree=2, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 8/81] START C=0.1, degree=2, epsilon=1, gamma=auto, kernel=poly........
# [CV 3/3; 8/81] END C=0.1, degree=2, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 9/81] START C=0.1, degree=2, epsilon=1, gamma=auto, kernel=rbf.........
# [CV 1/3; 9/81] END C=0.1, degree=2, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 9/81] START C=0.1, degree=2, epsilon=1, gamma=auto, kernel=rbf.........
# [CV 2/3; 9/81] END C=0.1, degree=2, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 9/81] START C=0.1, degree=2, epsilon=1, gamma=auto, kernel=rbf.........
# [CV 3/3; 9/81] END C=0.1, degree=2, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 10/81] START C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=linear.
# [CV 1/3; 10/81] END C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 10/81] START C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=linear.
# [CV 2/3; 10/81] END C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 10/81] START C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=linear.
# [CV 3/3; 10/81] END C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 11/81] START C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=poly...
# [CV 1/3; 11/81] END C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 11/81] START C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=poly...
# [CV 2/3; 11/81] END C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 11/81] START C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=poly...
# [CV 3/3; 11/81] END C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 12/81] START C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=rbf....
# [CV 1/3; 12/81] END C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 12/81] START C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=rbf....
# [CV 2/3; 12/81] END C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 12/81] START C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=rbf....
# [CV 3/3; 12/81] END C=0.1, degree=3, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 13/81] START C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=linear..
# [CV 1/3; 13/81] END C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 13/81] START C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=linear..
# [CV 2/3; 13/81] END C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 13/81] START C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=linear..
# [CV 3/3; 13/81] END C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 14/81] START C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=poly....
# [CV 1/3; 14/81] END C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 14/81] START C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=poly....
# [CV 2/3; 14/81] END C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 14/81] START C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=poly....
# [CV 3/3; 14/81] END C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 15/81] START C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=rbf.....
# [CV 1/3; 15/81] END C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 15/81] START C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=rbf.....
# [CV 2/3; 15/81] END C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 15/81] START C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=rbf.....
# [CV 3/3; 15/81] END C=0.1, degree=3, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 16/81] START C=0.1, degree=3, epsilon=1, gamma=auto, kernel=linear.....
# [CV 1/3; 16/81] END C=0.1, degree=3, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 16/81] START C=0.1, degree=3, epsilon=1, gamma=auto, kernel=linear.....
# [CV 2/3; 16/81] END C=0.1, degree=3, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 16/81] START C=0.1, degree=3, epsilon=1, gamma=auto, kernel=linear.....
# [CV 3/3; 16/81] END C=0.1, degree=3, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 17/81] START C=0.1, degree=3, epsilon=1, gamma=auto, kernel=poly.......
# [CV 1/3; 17/81] END C=0.1, degree=3, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 17/81] START C=0.1, degree=3, epsilon=1, gamma=auto, kernel=poly.......
# [CV 2/3; 17/81] END C=0.1, degree=3, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 17/81] START C=0.1, degree=3, epsilon=1, gamma=auto, kernel=poly.......
# [CV 3/3; 17/81] END C=0.1, degree=3, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 18/81] START C=0.1, degree=3, epsilon=1, gamma=auto, kernel=rbf........
# [CV 1/3; 18/81] END C=0.1, degree=3, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 18/81] START C=0.1, degree=3, epsilon=1, gamma=auto, kernel=rbf........
# [CV 2/3; 18/81] END C=0.1, degree=3, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 18/81] START C=0.1, degree=3, epsilon=1, gamma=auto, kernel=rbf........
# [CV 3/3; 18/81] END C=0.1, degree=3, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 19/81] START C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=linear.
# [CV 1/3; 19/81] END C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 19/81] START C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=linear.
# [CV 2/3; 19/81] END C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 19/81] START C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=linear.
# [CV 3/3; 19/81] END C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 20/81] START C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=poly...
# [CV 1/3; 20/81] END C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 20/81] START C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=poly...
# [CV 2/3; 20/81] END C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 20/81] START C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=poly...
# [CV 3/3; 20/81] END C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 21/81] START C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=rbf....
# [CV 1/3; 21/81] END C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 21/81] START C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=rbf....
# [CV 2/3; 21/81] END C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 21/81] START C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=rbf....
# [CV 3/3; 21/81] END C=0.1, degree=5, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 22/81] START C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=linear..
# [CV 1/3; 22/81] END C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 22/81] START C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=linear..
# [CV 2/3; 22/81] END C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 22/81] START C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=linear..
# [CV 3/3; 22/81] END C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 23/81] START C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=poly....
# [CV 1/3; 23/81] END C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 23/81] START C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=poly....
# [CV 2/3; 23/81] END C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 23/81] START C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=poly....
# [CV 3/3; 23/81] END C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 24/81] START C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=rbf.....
# [CV 1/3; 24/81] END C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 24/81] START C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=rbf.....
# [CV 2/3; 24/81] END C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 24/81] START C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=rbf.....
# [CV 3/3; 24/81] END C=0.1, degree=5, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 25/81] START C=0.1, degree=5, epsilon=1, gamma=auto, kernel=linear.....
# [CV 1/3; 25/81] END C=0.1, degree=5, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 25/81] START C=0.1, degree=5, epsilon=1, gamma=auto, kernel=linear.....
# [CV 2/3; 25/81] END C=0.1, degree=5, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 25/81] START C=0.1, degree=5, epsilon=1, gamma=auto, kernel=linear.....
# [CV 3/3; 25/81] END C=0.1, degree=5, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 26/81] START C=0.1, degree=5, epsilon=1, gamma=auto, kernel=poly.......
# [CV 1/3; 26/81] END C=0.1, degree=5, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 26/81] START C=0.1, degree=5, epsilon=1, gamma=auto, kernel=poly.......
# [CV 2/3; 26/81] END C=0.1, degree=5, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 26/81] START C=0.1, degree=5, epsilon=1, gamma=auto, kernel=poly.......
# [CV 3/3; 26/81] END C=0.1, degree=5, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 27/81] START C=0.1, degree=5, epsilon=1, gamma=auto, kernel=rbf........
# [CV 1/3; 27/81] END C=0.1, degree=5, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 27/81] START C=0.1, degree=5, epsilon=1, gamma=auto, kernel=rbf........
# [CV 2/3; 27/81] END C=0.1, degree=5, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 27/81] START C=0.1, degree=5, epsilon=1, gamma=auto, kernel=rbf........
# [CV 3/3; 27/81] END C=0.1, degree=5, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 28/81] START C=1, degree=2, epsilon=0.001, gamma=auto, kernel=linear...
# [CV 1/3; 28/81] END C=1, degree=2, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 28/81] START C=1, degree=2, epsilon=0.001, gamma=auto, kernel=linear...
# [CV 2/3; 28/81] END C=1, degree=2, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 28/81] START C=1, degree=2, epsilon=0.001, gamma=auto, kernel=linear...
# [CV 3/3; 28/81] END C=1, degree=2, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 29/81] START C=1, degree=2, epsilon=0.001, gamma=auto, kernel=poly.....
# [CV 1/3; 29/81] END C=1, degree=2, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 29/81] START C=1, degree=2, epsilon=0.001, gamma=auto, kernel=poly.....
# [CV 2/3; 29/81] END C=1, degree=2, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 29/81] START C=1, degree=2, epsilon=0.001, gamma=auto, kernel=poly.....
# [CV 3/3; 29/81] END C=1, degree=2, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 30/81] START C=1, degree=2, epsilon=0.001, gamma=auto, kernel=rbf......
# [CV 1/3; 30/81] END C=1, degree=2, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 30/81] START C=1, degree=2, epsilon=0.001, gamma=auto, kernel=rbf......
# [CV 2/3; 30/81] END C=1, degree=2, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 30/81] START C=1, degree=2, epsilon=0.001, gamma=auto, kernel=rbf......
# [CV 3/3; 30/81] END C=1, degree=2, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 31/81] START C=1, degree=2, epsilon=0.01, gamma=auto, kernel=linear....
# [CV 1/3; 31/81] END C=1, degree=2, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 31/81] START C=1, degree=2, epsilon=0.01, gamma=auto, kernel=linear....
# [CV 2/3; 31/81] END C=1, degree=2, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 31/81] START C=1, degree=2, epsilon=0.01, gamma=auto, kernel=linear....
# [CV 3/3; 31/81] END C=1, degree=2, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 32/81] START C=1, degree=2, epsilon=0.01, gamma=auto, kernel=poly......
# [CV 1/3; 32/81] END C=1, degree=2, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 32/81] START C=1, degree=2, epsilon=0.01, gamma=auto, kernel=poly......
# [CV 2/3; 32/81] END C=1, degree=2, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 32/81] START C=1, degree=2, epsilon=0.01, gamma=auto, kernel=poly......
# [CV 3/3; 32/81] END C=1, degree=2, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 33/81] START C=1, degree=2, epsilon=0.01, gamma=auto, kernel=rbf.......
# [CV 1/3; 33/81] END C=1, degree=2, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 33/81] START C=1, degree=2, epsilon=0.01, gamma=auto, kernel=rbf.......
# [CV 2/3; 33/81] END C=1, degree=2, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 33/81] START C=1, degree=2, epsilon=0.01, gamma=auto, kernel=rbf.......
# [CV 3/3; 33/81] END C=1, degree=2, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 34/81] START C=1, degree=2, epsilon=1, gamma=auto, kernel=linear.......
# [CV 1/3; 34/81] END C=1, degree=2, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 34/81] START C=1, degree=2, epsilon=1, gamma=auto, kernel=linear.......
# [CV 2/3; 34/81] END C=1, degree=2, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 34/81] START C=1, degree=2, epsilon=1, gamma=auto, kernel=linear.......
# [CV 3/3; 34/81] END C=1, degree=2, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 35/81] START C=1, degree=2, epsilon=1, gamma=auto, kernel=poly.........
# [CV 1/3; 35/81] END C=1, degree=2, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 35/81] START C=1, degree=2, epsilon=1, gamma=auto, kernel=poly.........
# [CV 2/3; 35/81] END C=1, degree=2, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 35/81] START C=1, degree=2, epsilon=1, gamma=auto, kernel=poly.........
# [CV 3/3; 35/81] END C=1, degree=2, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 36/81] START C=1, degree=2, epsilon=1, gamma=auto, kernel=rbf..........
# [CV 1/3; 36/81] END C=1, degree=2, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 36/81] START C=1, degree=2, epsilon=1, gamma=auto, kernel=rbf..........
# [CV 2/3; 36/81] END C=1, degree=2, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 36/81] START C=1, degree=2, epsilon=1, gamma=auto, kernel=rbf..........
# [CV 3/3; 36/81] END C=1, degree=2, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 37/81] START C=1, degree=3, epsilon=0.001, gamma=auto, kernel=linear...
# [CV 1/3; 37/81] END C=1, degree=3, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 37/81] START C=1, degree=3, epsilon=0.001, gamma=auto, kernel=linear...
# [CV 2/3; 37/81] END C=1, degree=3, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 37/81] START C=1, degree=3, epsilon=0.001, gamma=auto, kernel=linear...
# [CV 3/3; 37/81] END C=1, degree=3, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 38/81] START C=1, degree=3, epsilon=0.001, gamma=auto, kernel=poly.....
# [CV 1/3; 38/81] END C=1, degree=3, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 38/81] START C=1, degree=3, epsilon=0.001, gamma=auto, kernel=poly.....
# [CV 2/3; 38/81] END C=1, degree=3, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 38/81] START C=1, degree=3, epsilon=0.001, gamma=auto, kernel=poly.....
# [CV 3/3; 38/81] END C=1, degree=3, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 39/81] START C=1, degree=3, epsilon=0.001, gamma=auto, kernel=rbf......
# [CV 1/3; 39/81] END C=1, degree=3, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 39/81] START C=1, degree=3, epsilon=0.001, gamma=auto, kernel=rbf......
# [CV 2/3; 39/81] END C=1, degree=3, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 39/81] START C=1, degree=3, epsilon=0.001, gamma=auto, kernel=rbf......
# [CV 3/3; 39/81] END C=1, degree=3, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 40/81] START C=1, degree=3, epsilon=0.01, gamma=auto, kernel=linear....
# [CV 1/3; 40/81] END C=1, degree=3, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 40/81] START C=1, degree=3, epsilon=0.01, gamma=auto, kernel=linear....
# [CV 2/3; 40/81] END C=1, degree=3, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 40/81] START C=1, degree=3, epsilon=0.01, gamma=auto, kernel=linear....
# [CV 3/3; 40/81] END C=1, degree=3, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 41/81] START C=1, degree=3, epsilon=0.01, gamma=auto, kernel=poly......
# [CV 1/3; 41/81] END C=1, degree=3, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 41/81] START C=1, degree=3, epsilon=0.01, gamma=auto, kernel=poly......
# [CV 2/3; 41/81] END C=1, degree=3, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 41/81] START C=1, degree=3, epsilon=0.01, gamma=auto, kernel=poly......
# [CV 3/3; 41/81] END C=1, degree=3, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 42/81] START C=1, degree=3, epsilon=0.01, gamma=auto, kernel=rbf.......
# [CV 1/3; 42/81] END C=1, degree=3, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 42/81] START C=1, degree=3, epsilon=0.01, gamma=auto, kernel=rbf.......
# [CV 2/3; 42/81] END C=1, degree=3, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 42/81] START C=1, degree=3, epsilon=0.01, gamma=auto, kernel=rbf.......
# [CV 3/3; 42/81] END C=1, degree=3, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 43/81] START C=1, degree=3, epsilon=1, gamma=auto, kernel=linear.......
# [CV 1/3; 43/81] END C=1, degree=3, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 43/81] START C=1, degree=3, epsilon=1, gamma=auto, kernel=linear.......
# [CV 2/3; 43/81] END C=1, degree=3, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 43/81] START C=1, degree=3, epsilon=1, gamma=auto, kernel=linear.......
# [CV 3/3; 43/81] END C=1, degree=3, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 44/81] START C=1, degree=3, epsilon=1, gamma=auto, kernel=poly.........
# [CV 1/3; 44/81] END C=1, degree=3, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 44/81] START C=1, degree=3, epsilon=1, gamma=auto, kernel=poly.........
# [CV 2/3; 44/81] END C=1, degree=3, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 44/81] START C=1, degree=3, epsilon=1, gamma=auto, kernel=poly.........
# [CV 3/3; 44/81] END C=1, degree=3, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 45/81] START C=1, degree=3, epsilon=1, gamma=auto, kernel=rbf..........
# [CV 1/3; 45/81] END C=1, degree=3, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 45/81] START C=1, degree=3, epsilon=1, gamma=auto, kernel=rbf..........
# [CV 2/3; 45/81] END C=1, degree=3, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 45/81] START C=1, degree=3, epsilon=1, gamma=auto, kernel=rbf..........
# [CV 3/3; 45/81] END C=1, degree=3, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 46/81] START C=1, degree=5, epsilon=0.001, gamma=auto, kernel=linear...
# [CV 1/3; 46/81] END C=1, degree=5, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 46/81] START C=1, degree=5, epsilon=0.001, gamma=auto, kernel=linear...
# [CV 2/3; 46/81] END C=1, degree=5, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 46/81] START C=1, degree=5, epsilon=0.001, gamma=auto, kernel=linear...
# [CV 3/3; 46/81] END C=1, degree=5, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 47/81] START C=1, degree=5, epsilon=0.001, gamma=auto, kernel=poly.....
# [CV 1/3; 47/81] END C=1, degree=5, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 47/81] START C=1, degree=5, epsilon=0.001, gamma=auto, kernel=poly.....
# [CV 2/3; 47/81] END C=1, degree=5, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 47/81] START C=1, degree=5, epsilon=0.001, gamma=auto, kernel=poly.....
# [CV 3/3; 47/81] END C=1, degree=5, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 48/81] START C=1, degree=5, epsilon=0.001, gamma=auto, kernel=rbf......
# [CV 1/3; 48/81] END C=1, degree=5, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 48/81] START C=1, degree=5, epsilon=0.001, gamma=auto, kernel=rbf......
# [CV 2/3; 48/81] END C=1, degree=5, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 48/81] START C=1, degree=5, epsilon=0.001, gamma=auto, kernel=rbf......
# [CV 3/3; 48/81] END C=1, degree=5, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 49/81] START C=1, degree=5, epsilon=0.01, gamma=auto, kernel=linear....
# [CV 1/3; 49/81] END C=1, degree=5, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 49/81] START C=1, degree=5, epsilon=0.01, gamma=auto, kernel=linear....
# [CV 2/3; 49/81] END C=1, degree=5, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 49/81] START C=1, degree=5, epsilon=0.01, gamma=auto, kernel=linear....
# [CV 3/3; 49/81] END C=1, degree=5, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 50/81] START C=1, degree=5, epsilon=0.01, gamma=auto, kernel=poly......
# [CV 1/3; 50/81] END C=1, degree=5, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 50/81] START C=1, degree=5, epsilon=0.01, gamma=auto, kernel=poly......
# [CV 2/3; 50/81] END C=1, degree=5, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 50/81] START C=1, degree=5, epsilon=0.01, gamma=auto, kernel=poly......
# [CV 3/3; 50/81] END C=1, degree=5, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 51/81] START C=1, degree=5, epsilon=0.01, gamma=auto, kernel=rbf.......
# [CV 1/3; 51/81] END C=1, degree=5, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 51/81] START C=1, degree=5, epsilon=0.01, gamma=auto, kernel=rbf.......
# [CV 2/3; 51/81] END C=1, degree=5, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 51/81] START C=1, degree=5, epsilon=0.01, gamma=auto, kernel=rbf.......
# [CV 3/3; 51/81] END C=1, degree=5, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 52/81] START C=1, degree=5, epsilon=1, gamma=auto, kernel=linear.......
# [CV 1/3; 52/81] END C=1, degree=5, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 52/81] START C=1, degree=5, epsilon=1, gamma=auto, kernel=linear.......
# [CV 2/3; 52/81] END C=1, degree=5, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 52/81] START C=1, degree=5, epsilon=1, gamma=auto, kernel=linear.......
# [CV 3/3; 52/81] END C=1, degree=5, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 53/81] START C=1, degree=5, epsilon=1, gamma=auto, kernel=poly.........
# [CV 1/3; 53/81] END C=1, degree=5, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 53/81] START C=1, degree=5, epsilon=1, gamma=auto, kernel=poly.........
# [CV 2/3; 53/81] END C=1, degree=5, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 53/81] START C=1, degree=5, epsilon=1, gamma=auto, kernel=poly.........
# [CV 3/3; 53/81] END C=1, degree=5, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 54/81] START C=1, degree=5, epsilon=1, gamma=auto, kernel=rbf..........
# [CV 1/3; 54/81] END C=1, degree=5, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 54/81] START C=1, degree=5, epsilon=1, gamma=auto, kernel=rbf..........
# [CV 2/3; 54/81] END C=1, degree=5, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 54/81] START C=1, degree=5, epsilon=1, gamma=auto, kernel=rbf..........
# [CV 3/3; 54/81] END C=1, degree=5, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 55/81] START C=10, degree=2, epsilon=0.001, gamma=auto, kernel=linear..
# [CV 1/3; 55/81] END C=10, degree=2, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 55/81] START C=10, degree=2, epsilon=0.001, gamma=auto, kernel=linear..
# [CV 2/3; 55/81] END C=10, degree=2, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 55/81] START C=10, degree=2, epsilon=0.001, gamma=auto, kernel=linear..
# [CV 3/3; 55/81] END C=10, degree=2, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 56/81] START C=10, degree=2, epsilon=0.001, gamma=auto, kernel=poly....
# [CV 1/3; 56/81] END C=10, degree=2, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 56/81] START C=10, degree=2, epsilon=0.001, gamma=auto, kernel=poly....
# [CV 2/3; 56/81] END C=10, degree=2, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 56/81] START C=10, degree=2, epsilon=0.001, gamma=auto, kernel=poly....
# [CV 3/3; 56/81] END C=10, degree=2, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 57/81] START C=10, degree=2, epsilon=0.001, gamma=auto, kernel=rbf.....
# [CV 1/3; 57/81] END C=10, degree=2, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 57/81] START C=10, degree=2, epsilon=0.001, gamma=auto, kernel=rbf.....
# [CV 2/3; 57/81] END C=10, degree=2, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 57/81] START C=10, degree=2, epsilon=0.001, gamma=auto, kernel=rbf.....
# [CV 3/3; 57/81] END C=10, degree=2, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 58/81] START C=10, degree=2, epsilon=0.01, gamma=auto, kernel=linear...
# [CV 1/3; 58/81] END C=10, degree=2, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 58/81] START C=10, degree=2, epsilon=0.01, gamma=auto, kernel=linear...
# [CV 2/3; 58/81] END C=10, degree=2, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 58/81] START C=10, degree=2, epsilon=0.01, gamma=auto, kernel=linear...
# [CV 3/3; 58/81] END C=10, degree=2, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 59/81] START C=10, degree=2, epsilon=0.01, gamma=auto, kernel=poly.....
# [CV 1/3; 59/81] END C=10, degree=2, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 59/81] START C=10, degree=2, epsilon=0.01, gamma=auto, kernel=poly.....
# [CV 2/3; 59/81] END C=10, degree=2, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 59/81] START C=10, degree=2, epsilon=0.01, gamma=auto, kernel=poly.....
# [CV 3/3; 59/81] END C=10, degree=2, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 60/81] START C=10, degree=2, epsilon=0.01, gamma=auto, kernel=rbf......
# [CV 1/3; 60/81] END C=10, degree=2, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 60/81] START C=10, degree=2, epsilon=0.01, gamma=auto, kernel=rbf......
# [CV 2/3; 60/81] END C=10, degree=2, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 60/81] START C=10, degree=2, epsilon=0.01, gamma=auto, kernel=rbf......
# [CV 3/3; 60/81] END C=10, degree=2, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 61/81] START C=10, degree=2, epsilon=1, gamma=auto, kernel=linear......
# [CV 1/3; 61/81] END C=10, degree=2, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 61/81] START C=10, degree=2, epsilon=1, gamma=auto, kernel=linear......
# [CV 2/3; 61/81] END C=10, degree=2, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 61/81] START C=10, degree=2, epsilon=1, gamma=auto, kernel=linear......
# [CV 3/3; 61/81] END C=10, degree=2, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 62/81] START C=10, degree=2, epsilon=1, gamma=auto, kernel=poly........
# [CV 1/3; 62/81] END C=10, degree=2, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 62/81] START C=10, degree=2, epsilon=1, gamma=auto, kernel=poly........
# [CV 2/3; 62/81] END C=10, degree=2, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 62/81] START C=10, degree=2, epsilon=1, gamma=auto, kernel=poly........
# [CV 3/3; 62/81] END C=10, degree=2, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 63/81] START C=10, degree=2, epsilon=1, gamma=auto, kernel=rbf.........
# [CV 1/3; 63/81] END C=10, degree=2, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 63/81] START C=10, degree=2, epsilon=1, gamma=auto, kernel=rbf.........
# [CV 2/3; 63/81] END C=10, degree=2, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 63/81] START C=10, degree=2, epsilon=1, gamma=auto, kernel=rbf.........
# [CV 3/3; 63/81] END C=10, degree=2, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 64/81] START C=10, degree=3, epsilon=0.001, gamma=auto, kernel=linear..
# [CV 1/3; 64/81] END C=10, degree=3, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 64/81] START C=10, degree=3, epsilon=0.001, gamma=auto, kernel=linear..
# [CV 2/3; 64/81] END C=10, degree=3, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 64/81] START C=10, degree=3, epsilon=0.001, gamma=auto, kernel=linear..
# [CV 3/3; 64/81] END C=10, degree=3, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 65/81] START C=10, degree=3, epsilon=0.001, gamma=auto, kernel=poly....
# [CV 1/3; 65/81] END C=10, degree=3, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 65/81] START C=10, degree=3, epsilon=0.001, gamma=auto, kernel=poly....
# [CV 2/3; 65/81] END C=10, degree=3, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 65/81] START C=10, degree=3, epsilon=0.001, gamma=auto, kernel=poly....
# [CV 3/3; 65/81] END C=10, degree=3, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 66/81] START C=10, degree=3, epsilon=0.001, gamma=auto, kernel=rbf.....
# [CV 1/3; 66/81] END C=10, degree=3, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 66/81] START C=10, degree=3, epsilon=0.001, gamma=auto, kernel=rbf.....
# [CV 2/3; 66/81] END C=10, degree=3, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 66/81] START C=10, degree=3, epsilon=0.001, gamma=auto, kernel=rbf.....
# [CV 3/3; 66/81] END C=10, degree=3, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 67/81] START C=10, degree=3, epsilon=0.01, gamma=auto, kernel=linear...
# [CV 1/3; 67/81] END C=10, degree=3, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 67/81] START C=10, degree=3, epsilon=0.01, gamma=auto, kernel=linear...
# [CV 2/3; 67/81] END C=10, degree=3, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 67/81] START C=10, degree=3, epsilon=0.01, gamma=auto, kernel=linear...
# [CV 3/3; 67/81] END C=10, degree=3, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 68/81] START C=10, degree=3, epsilon=0.01, gamma=auto, kernel=poly.....
# [CV 1/3; 68/81] END C=10, degree=3, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 68/81] START C=10, degree=3, epsilon=0.01, gamma=auto, kernel=poly.....
# [CV 2/3; 68/81] END C=10, degree=3, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 68/81] START C=10, degree=3, epsilon=0.01, gamma=auto, kernel=poly.....
# [CV 3/3; 68/81] END C=10, degree=3, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 69/81] START C=10, degree=3, epsilon=0.01, gamma=auto, kernel=rbf......
# [CV 1/3; 69/81] END C=10, degree=3, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 69/81] START C=10, degree=3, epsilon=0.01, gamma=auto, kernel=rbf......
# [CV 2/3; 69/81] END C=10, degree=3, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 69/81] START C=10, degree=3, epsilon=0.01, gamma=auto, kernel=rbf......
# [CV 3/3; 69/81] END C=10, degree=3, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 70/81] START C=10, degree=3, epsilon=1, gamma=auto, kernel=linear......
# [CV 1/3; 70/81] END C=10, degree=3, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 70/81] START C=10, degree=3, epsilon=1, gamma=auto, kernel=linear......
# [CV 2/3; 70/81] END C=10, degree=3, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 70/81] START C=10, degree=3, epsilon=1, gamma=auto, kernel=linear......
# [CV 3/3; 70/81] END C=10, degree=3, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 71/81] START C=10, degree=3, epsilon=1, gamma=auto, kernel=poly........
# [CV 1/3; 71/81] END C=10, degree=3, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 71/81] START C=10, degree=3, epsilon=1, gamma=auto, kernel=poly........
# [CV 2/3; 71/81] END C=10, degree=3, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 71/81] START C=10, degree=3, epsilon=1, gamma=auto, kernel=poly........
# [CV 3/3; 71/81] END C=10, degree=3, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 72/81] START C=10, degree=3, epsilon=1, gamma=auto, kernel=rbf.........
# [CV 1/3; 72/81] END C=10, degree=3, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 72/81] START C=10, degree=3, epsilon=1, gamma=auto, kernel=rbf.........
# [CV 2/3; 72/81] END C=10, degree=3, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 72/81] START C=10, degree=3, epsilon=1, gamma=auto, kernel=rbf.........
# [CV 3/3; 72/81] END C=10, degree=3, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 73/81] START C=10, degree=5, epsilon=0.001, gamma=auto, kernel=linear..
# [CV 1/3; 73/81] END C=10, degree=5, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 73/81] START C=10, degree=5, epsilon=0.001, gamma=auto, kernel=linear..
# [CV 2/3; 73/81] END C=10, degree=5, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 73/81] START C=10, degree=5, epsilon=0.001, gamma=auto, kernel=linear..
# [CV 3/3; 73/81] END C=10, degree=5, epsilon=0.001, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 74/81] START C=10, degree=5, epsilon=0.001, gamma=auto, kernel=poly....
# [CV 1/3; 74/81] END C=10, degree=5, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 74/81] START C=10, degree=5, epsilon=0.001, gamma=auto, kernel=poly....
# [CV 2/3; 74/81] END C=10, degree=5, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 74/81] START C=10, degree=5, epsilon=0.001, gamma=auto, kernel=poly....
# [CV 3/3; 74/81] END C=10, degree=5, epsilon=0.001, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 75/81] START C=10, degree=5, epsilon=0.001, gamma=auto, kernel=rbf.....
# [CV 1/3; 75/81] END C=10, degree=5, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 75/81] START C=10, degree=5, epsilon=0.001, gamma=auto, kernel=rbf.....
# [CV 2/3; 75/81] END C=10, degree=5, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 75/81] START C=10, degree=5, epsilon=0.001, gamma=auto, kernel=rbf.....
# [CV 3/3; 75/81] END C=10, degree=5, epsilon=0.001, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 76/81] START C=10, degree=5, epsilon=0.01, gamma=auto, kernel=linear...
# [CV 1/3; 76/81] END C=10, degree=5, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 76/81] START C=10, degree=5, epsilon=0.01, gamma=auto, kernel=linear...
# [CV 2/3; 76/81] END C=10, degree=5, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 76/81] START C=10, degree=5, epsilon=0.01, gamma=auto, kernel=linear...
# [CV 3/3; 76/81] END C=10, degree=5, epsilon=0.01, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 77/81] START C=10, degree=5, epsilon=0.01, gamma=auto, kernel=poly.....
# [CV 1/3; 77/81] END C=10, degree=5, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 77/81] START C=10, degree=5, epsilon=0.01, gamma=auto, kernel=poly.....
# [CV 2/3; 77/81] END C=10, degree=5, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 77/81] START C=10, degree=5, epsilon=0.01, gamma=auto, kernel=poly.....
# [CV 3/3; 77/81] END C=10, degree=5, epsilon=0.01, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 78/81] START C=10, degree=5, epsilon=0.01, gamma=auto, kernel=rbf......
# [CV 1/3; 78/81] END C=10, degree=5, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 78/81] START C=10, degree=5, epsilon=0.01, gamma=auto, kernel=rbf......
# [CV 2/3; 78/81] END C=10, degree=5, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 78/81] START C=10, degree=5, epsilon=0.01, gamma=auto, kernel=rbf......
# [CV 3/3; 78/81] END C=10, degree=5, epsilon=0.01, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 1/3; 79/81] START C=10, degree=5, epsilon=1, gamma=auto, kernel=linear......
# [CV 1/3; 79/81] END C=10, degree=5, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 2/3; 79/81] START C=10, degree=5, epsilon=1, gamma=auto, kernel=linear......
# [CV 2/3; 79/81] END C=10, degree=5, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 3/3; 79/81] START C=10, degree=5, epsilon=1, gamma=auto, kernel=linear......
# [CV 3/3; 79/81] END C=10, degree=5, epsilon=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV 1/3; 80/81] START C=10, degree=5, epsilon=1, gamma=auto, kernel=poly........
# [CV 1/3; 80/81] END C=10, degree=5, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 2/3; 80/81] START C=10, degree=5, epsilon=1, gamma=auto, kernel=poly........
# [CV 2/3; 80/81] END C=10, degree=5, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 3/3; 80/81] START C=10, degree=5, epsilon=1, gamma=auto, kernel=poly........
# [CV 3/3; 80/81] END C=10, degree=5, epsilon=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV 1/3; 81/81] START C=10, degree=5, epsilon=1, gamma=auto, kernel=rbf.........
# [CV 1/3; 81/81] END C=10, degree=5, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 2/3; 81/81] START C=10, degree=5, epsilon=1, gamma=auto, kernel=rbf.........
# [CV 2/3; 81/81] END C=10, degree=5, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV 3/3; 81/81] START C=10, degree=5, epsilon=1, gamma=auto, kernel=rbf.........
# [CV 3/3; 81/81] END C=10, degree=5, epsilon=1, gamma=auto, kernel=rbf; total time=   0.0s

# %%
#summarize the results of your GRIDSEARCH
print('***GRIDSEARCH RESULTS***')
print("Best score: %f using %s" % (gs.best_score_, gs.best_params_))
means = gs.cv_results_['mean_test_score']
stds = gs.cv_results_['std_test_score']
params = gs.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

#Returns the coefficient of determination R^2 of the prediction.
#Explained variance score: 1 is perfect prediction
gs.score(X_test, y_test)
# Out:
# ***GRIDSEARCH RESULTS***
# Best score: -2.136486 using {'C': 10, 'degree': 2, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.883030 (0.220945) with: {'C': 0.1, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'linear'}
# -5.465485 (0.200861) with: {'C': 0.1, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'poly'}
# -5.068328 (0.268062) with: {'C': 0.1, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.882395 (0.221609) with: {'C': 0.1, 'degree': 2, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'linear'}
# -5.465165 (0.200686) with: {'C': 0.1, 'degree': 2, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'poly'}
# -5.067447 (0.267124) with: {'C': 0.1, 'degree': 2, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.882262 (0.239209) with: {'C': 0.1, 'degree': 2, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'linear'}
# -5.484649 (0.196579) with: {'C': 0.1, 'degree': 2, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'poly'}
# -5.080986 (0.283177) with: {'C': 0.1, 'degree': 2, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.883030 (0.220945) with: {'C': 0.1, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'linear'}
# -4.357566 (0.248823) with: {'C': 0.1, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'poly'}
# -5.068328 (0.268062) with: {'C': 0.1, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.882395 (0.221609) with: {'C': 0.1, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'linear'}
# -4.357997 (0.248607) with: {'C': 0.1, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'poly'}
# -5.067447 (0.267124) with: {'C': 0.1, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.882262 (0.239209) with: {'C': 0.1, 'degree': 3, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'linear'}
# -4.394035 (0.241279) with: {'C': 0.1, 'degree': 3, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'poly'}
# -5.080986 (0.283177) with: {'C': 0.1, 'degree': 3, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.883030 (0.220945) with: {'C': 0.1, 'degree': 5, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'linear'}
# -4.583258 (0.268363) with: {'C': 0.1, 'degree': 5, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'poly'}
# -5.068328 (0.268062) with: {'C': 0.1, 'degree': 5, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.882395 (0.221609) with: {'C': 0.1, 'degree': 5, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'linear'}
# -4.583161 (0.267680) with: {'C': 0.1, 'degree': 5, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'poly'}
# -5.067447 (0.267124) with: {'C': 0.1, 'degree': 5, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.882262 (0.239209) with: {'C': 0.1, 'degree': 5, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'linear'}
# -4.552195 (0.232686) with: {'C': 0.1, 'degree': 5, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'poly'}
# -5.080986 (0.283177) with: {'C': 0.1, 'degree': 5, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.855939 (0.212433) with: {'C': 1, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'linear'}
# -4.414660 (0.137338) with: {'C': 1, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'poly'}
# -3.027055 (0.194120) with: {'C': 1, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.855559 (0.211539) with: {'C': 1, 'degree': 2, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'linear'}
# -4.412940 (0.138007) with: {'C': 1, 'degree': 2, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'poly'}
# -3.026915 (0.193725) with: {'C': 1, 'degree': 2, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.845664 (0.230262) with: {'C': 1, 'degree': 2, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'linear'}
# -4.340039 (0.174490) with: {'C': 1, 'degree': 2, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'poly'}
# -3.069409 (0.205077) with: {'C': 1, 'degree': 2, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.855939 (0.212433) with: {'C': 1, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'linear'}
# -3.565295 (0.282456) with: {'C': 1, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'poly'}
# -3.027055 (0.194120) with: {'C': 1, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.855559 (0.211539) with: {'C': 1, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'linear'}
# -3.565682 (0.282419) with: {'C': 1, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'poly'}
# -3.026915 (0.193725) with: {'C': 1, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.845664 (0.230262) with: {'C': 1, 'degree': 3, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'linear'}
# -3.559008 (0.271638) with: {'C': 1, 'degree': 3, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'poly'}
# -3.069409 (0.205077) with: {'C': 1, 'degree': 3, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.855939 (0.212433) with: {'C': 1, 'degree': 5, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'linear'}
# -3.818028 (0.366476) with: {'C': 1, 'degree': 5, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'poly'}
# -3.027055 (0.194120) with: {'C': 1, 'degree': 5, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.855559 (0.211539) with: {'C': 1, 'degree': 5, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'linear'}
# -3.818289 (0.366261) with: {'C': 1, 'degree': 5, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'poly'}
# -3.026915 (0.193725) with: {'C': 1, 'degree': 5, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.845664 (0.230262) with: {'C': 1, 'degree': 5, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'linear'}
# -3.849650 (0.306443) with: {'C': 1, 'degree': 5, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'poly'}
# -3.069409 (0.205077) with: {'C': 1, 'degree': 5, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.872581 (0.215724) with: {'C': 10, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'linear'}
# -3.587806 (0.164851) with: {'C': 10, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'poly'}
# -2.137251 (0.295054) with: {'C': 10, 'degree': 2, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.869998 (0.217513) with: {'C': 10, 'degree': 2, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'linear'}
# -3.586683 (0.163970) with: {'C': 10, 'degree': 2, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'poly'}
# -2.136757 (0.294430) with: {'C': 10, 'degree': 2, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.849755 (0.231667) with: {'C': 10, 'degree': 2, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'linear'}
# -3.531729 (0.121185) with: {'C': 10, 'degree': 2, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'poly'}
# -2.136486 (0.243283) with: {'C': 10, 'degree': 2, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.872581 (0.215724) with: {'C': 10, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'linear'}
# -3.250377 (0.425022) with: {'C': 10, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'poly'}
# -2.137251 (0.295054) with: {'C': 10, 'degree': 3, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.869998 (0.217513) with: {'C': 10, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'linear'}
# -3.248210 (0.424278) with: {'C': 10, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'poly'}
# -2.136757 (0.294430) with: {'C': 10, 'degree': 3, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.849755 (0.231667) with: {'C': 10, 'degree': 3, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'linear'}
# -3.135934 (0.421775) with: {'C': 10, 'degree': 3, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'poly'}
# -2.136486 (0.243283) with: {'C': 10, 'degree': 3, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.872581 (0.215724) with: {'C': 10, 'degree': 5, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'linear'}
# -4.267709 (0.796563) with: {'C': 10, 'degree': 5, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'poly'}
# -2.137251 (0.295054) with: {'C': 10, 'degree': 5, 'epsilon': 0.001, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.869998 (0.217513) with: {'C': 10, 'degree': 5, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'linear'}
# -4.264195 (0.797114) with: {'C': 10, 'degree': 5, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'poly'}
# -2.136757 (0.294430) with: {'C': 10, 'degree': 5, 'epsilon': 0.01, 'gamma': 'auto', 'kernel': 'rbf'}
# -2.849755 (0.231667) with: {'C': 10, 'degree': 5, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'linear'}
# -3.890344 (0.656690) with: {'C': 10, 'degree': 5, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'poly'}
# -2.136486 (0.243283) with: {'C': 10, 'degree': 5, 'epsilon': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# -1.9891810174827986

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.scatter(gs.predict(X_train),gs.predict(X_train)-y_train, c="b", label="training data")
plt.scatter(gs.predict(X_test),gs.predict(X_test)-y_test, c="g", label="hold out data")
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.legend(loc="upper left")
plt.hlines(y=0, xmin=-10, xmax=50, color="r")
plt.xlim([-10,50])
plt.show()

# %%
from sklearn import metrics

print("MAE train: ", metrics.mean_absolute_error(y_train, gs.predict(X_train))) 
print("MSE train: ",metrics.mean_squared_error(y_train, gs.predict(X_train)))
print("RMSE train: ",np.sqrt(metrics.mean_squared_error(y_train, gs.predict(X_train))))
print("r2: ",np.sqrt(metrics.r2_score(y_train, gs.predict(X_train))))

print("MAE test: ", metrics.mean_absolute_error(y_test, gs.predict(X_test))) 
print("MSE test: ",metrics.mean_squared_error(y_test, gs.predict(X_test)))
print("RMSE test: ",np.sqrt(metrics.mean_squared_error(y_test, gs.predict(X_test))))
print("r2: ",np.sqrt(metrics.r2_score(y_test, gs.predict(X_test))))
# Out:
# MAE train:  1.547490725900786
# MSE train:  5.134412048838637
# RMSE train:  2.265924104827573
# r2:  0.9595895561156058
# MAE test:  1.9891810174827986
# MSE test:  7.8953150548909035
# RMSE test:  2.80986032658047
# r2:  0.9217564427943157
